# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('nau.csv')

# %%
df.head(50)
# Out:
#     index                                       Name             Location  \
# 0       0                       Princeton University        Princeton, NJ
# 1       1                         Harvard University        Cambridge, MA
# 2       2                      University of Chicago          Chicago, IL
# 3       3                            Yale University        New Haven, CT
# 4       4                        Columbia University         New York, NY
# 5       5                        Stanford University         Stanford, CA
# 6       6      Massachusetts Institute of Technology        Cambridge, MA
# 7       7                            Duke University           Durham, NC
# 8       8                 University of Pennsylvania     Philadelphia, PA
# 9       9                   Johns Hopkins University        Baltimore, MD
# 10     10                          Dartmouth College          Hanover, NH
# 11     11         California Institute of Technology         Pasadena, CA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231 entries, 0 to 230
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 231 non-null    int64
#  1   Name                  231 non-null    object
#  2   Location              231 non-null    object
#  3   Rank                  231 non-null    int64
#  4   Description           231 non-null    object
#  5   Tuition and fees      231 non-null    object
#  6   In-state              133 non-null    object
#  7   Undergrad Enrollment  231 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 14.6+ KB

# %%
df.describe()
# Out:
#             index        Rank
# count  231.000000  231.000000
# mean   115.000000  113.982684
# std     66.828138   65.995518
# min      0.000000    1.000000
# 25%     57.500000   56.000000
# 50%    115.000000  111.000000
# 75%    172.500000  171.000000
# max    230.000000  220.000000

# %%
df.dropna()
# Out:
#      index                                       Name             Location  \
# 21      21         University of California--Berkeley         Berkeley, CA
# 24      24      University of California--Los Angeles      Los Angeles, CA
# 25      25                     University of Virginia  Charlottesville, VA
# 27      27          University of Michigan--Ann Arbor        Ann Arbor, MI
# 29      29  University of North Carolina--Chapel Hill      Chapel Hill, NC
# ..     ...                                        ...                  ...
# 226    226     University of Massachusetts--Dartmouth  North Dartmouth, MA
# 227    227          University of Missouri--St. Louis        St. Louis, MO
# 228    228   University of North Carolina--Greensboro       Greensboro, NC
# 229    229         University of Southern Mississippi      Hattiesburg, MS
# 230    230                      Utah State University            Logan, UT
#
# ...

# %%
natur = df.copy()

# %%
natur.isna().sum()
# Out:
# index                    0
# Name                     0
# Location                 0
# Rank                     0
# Description              0
# Tuition and fees         0
# In-state                98
# Undergrad Enrollment     0
# dtype: int64

# %%
natur.dropna()
# Out:
#      index                                       Name             Location  \
# 21      21         University of California--Berkeley         Berkeley, CA
# 24      24      University of California--Los Angeles      Los Angeles, CA
# 25      25                     University of Virginia  Charlottesville, VA
# 27      27          University of Michigan--Ann Arbor        Ann Arbor, MI
# 29      29  University of North Carolina--Chapel Hill      Chapel Hill, NC
# ..     ...                                        ...                  ...
# 226    226     University of Massachusetts--Dartmouth  North Dartmouth, MA
# 227    227          University of Missouri--St. Louis        St. Louis, MO
# 228    228   University of North Carolina--Greensboro       Greensboro, NC
# 229    229         University of Southern Mississippi      Hattiesburg, MS
# 230    230                      Utah State University            Logan, UT
#
# ...

# %%
natur['In-state'] = natur['In-state'].str.replace('$','').str.replace(',', '')
natur['In-state'] = natur['In-state'].fillna('0').astype(int)
# Out:
# C:\Users\Uyanwune chekwube\AppData\Local\Temp\ipykernel_5804\2990300893.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   natur['In-state'] = natur['In-state'].str.replace('$','').str.replace(',', '')

# %%
natur['In-state'].sample(10)
# Out:
# 72     13790
# 229     7224
# 92      8880
# 140    11000
# 45     14705
# 55        NaN
# 187    10012
# 16        NaN
# 108       NaN
# 104    10762
# Name: In-state, dtype: object

# %%
natur.sample(10)
# Out:
#      index                                      Name        Location  Rank  \
# 4        4                       Columbia University    New York, NY     5
# 162    162               University of South Florida       Tampa, FL   159
# 170    170                          Edgewood College     Madison, WI   171
# 217    217  Southern Illinois University--Carbondale  Carbondale, IL   214
# 112    112                    University of Missouri    Columbia, MO   111
# 172    172                       University of Idaho      Moscow, ID   171
# 195    195               Western Michigan University   Kalamazoo, MI   194
# 125    125                       Duquesne University  Pittsburgh, PA   124
# 223    223                     Shenandoah University  Winchester, VA   220
# 149    149                University at Albany--SUNY      Albany, NY   146
#
#                                            Description Tuition and fees  \
# ...

# %%
natur.dropna()
# Out:
#      index                                      Name             Location  \
# 0        0                      Princeton University        Princeton, NJ
# 1        1                        Harvard University        Cambridge, MA
# 2        2                     University of Chicago          Chicago, IL
# 3        3                           Yale University        New Haven, CT
# 4        4                       Columbia University         New York, NY
# ..     ...                                       ...                  ...
# 226    226    University of Massachusetts--Dartmouth  North Dartmouth, MA
# 227    227         University of Missouri--St. Louis        St. Louis, MO
# 228    228  University of North Carolina--Greensboro       Greensboro, NC
# 229    229        University of Southern Mississippi      Hattiesburg, MS
# 230    230                     Utah State University            Logan, UT
#
#      Rank                                        Description Tuition and fees  \
# ...

# %%
natur['In-state'] = natur['In-state'].fillna('0').astype(int)
